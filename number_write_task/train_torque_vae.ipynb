# %% [markdown]
# Training conditional VAE on torque level with DMP

# %%
import os, time, tqdm, sys
import numpy as np
import torch

# add parent directory to path
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

from models.dmp import CanonicalSystem, SingleDMP
from models.vae import DmpCVAE, DM
from torch.utils.data import DataLoader
from utils.data_loader import TorqueLoader as Torque_dataset
from utils.early_stop import EarlyStop
from matplotlib import pyplot as plt
print(os.getcwd())
# Out:
# /home/binzhao/Documents/VAE_DMP_mani/number_write_task

# %%
# create model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

run_time = 1
dt = 0.01
shape = (2, 100)
# create dataset for training and testing
cs = CanonicalSystem(dt=0.01, ax=1)
dmp = SingleDMP(n_bfs=50, cs=cs, run_time=1.0, dt=0.01)

# %% [markdown]
# Load the data and normalize the data

# %%
train_dataset = Torque_dataset(run_time=1, dmp=dmp, dt=0.01, dof=2)
test_dataset = Torque_dataset(run_time=1, dmp=dmp, dt=0.01, dof=2)
train_dataset.load_data('../data/number_write/train_torque.npz', device=device)
test_dataset.load_data('../data/number_write/test_torque.npz', device=device)

train_dataset.torque = train_dataset.normalize_data(device=device)
test_dataset.torque = test_dataset.normalize_data(device=device)

print("train dataset size: ", len(train_dataset))
print("test dataset size: ", len(test_dataset))
# Out:
# train dataset size:  50000
# test dataset size:  1000

# %%
# create dataloader for training and testing
train_iter = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_iter = DataLoader(test_dataset, batch_size=64, shuffle=True)
vae_net = DmpCVAE(dmp=dmp, shape=shape, nclass=10, nhid=8, ncond=8)
vae_net.to(device)
# Out:
# DmpCVAE(
#   (encoder): Encoder(
#     (encode): Sequential(
#       (0): Conv1d(2, 16, kernel_size=(5,), stride=(2,))
#       (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv1d(16, 32, kernel_size=(5,), stride=(2,))
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (7): Conv1d(32, 64, kernel_size=(3,), stride=(2,))
#       (8): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (9): ReLU(inplace=True)
#       (10): Conv1d(64, 64, kernel_size=(3,), stride=(2,))
#       (11): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (12): ReLU(inplace=True)
#       (13): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (14): Flatten()
#       (15): MLP(
#         (mlp): Sequential(
#           (Linear_0): Linear(in_features=64, out_features=64, bias=True)
#           (ReLU_0): ReLU(inplace=True)
#         )
#       )
#     )
#     (calc_mean): MLP(
#       (mlp): Sequential(
#         (Linear_0): Linear(in_features=72, out_features=32, bias=True)
#         (ReLU_0): ReLU(inplace=True)
#         (Linear_1): Linear(in_features=32, out_features=16, bias=True)
#       )
#     )
#     (calc_logvar): MLP(
#       (mlp): Sequential(
#         (Linear_0): Linear(in_features=72, out_features=16, bias=True)
#         (ReLU_0): ReLU(inplace=True)
#         (Linear_1): Linear(in_features=16, out_features=16, bias=True)
#       )
#     )
#   )
#   (decoder): Decoder(
#     (decode): Sequential(
#       (0): MLP(
#         (mlp): Sequential(
#           (Linear_0): Linear(in_features=24, out_features=64, bias=True)
#           (ReLU_0): ReLU(inplace=True)
#           (Linear_1): Linear(in_features=64, out_features=128, bias=True)
#           (ReLU_1): ReLU(inplace=True)
#           (Linear_2): Linear(in_features=128, out_features=200, bias=True)
#         )
#       )
#       (1): Sigmoid()
#     )
#   )
#   (label_embedding): Embedding(10, 8)
#   (mse_loss): MSELoss()
#   (dmp): SingleDMP()
# )

# %%
number = 3
for x, y in train_iter:
    # get index of y equal to number
    index = torch.where(y == number)[0]
    plt.plot(x[index, 0, :].cpu().T, x[index, 1, :].cpu().T)
plt.title("Test data set for number " + str(number))
plt.axis('equal')
plt.show()
# Out:
# /home/binzhao/Documents/VAE_DMP_mani/utils/data_loader.py:220: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3675.)
#   return torque.T, label.T

# %%
# %% train model
lr = 1e-4
optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, vae_net.parameters()), lr=lr, weight_decay=0.0001)

def adjust_lr(optimizer, decay_rate=0.95):
    for param_group in optimizer.param_groups:
        param_group['lr'] *= decay_rate

# %% [markdown]
# Define the early stop function, load the function

# %%
# %% if load
save_name = "cVAE_torque.pt"
retrain = True
if os.path.exists(save_name):
    print("Model parameters have already been trained before. Retrain ? (y/n)")
    ans = input()
    if not (ans == 'y'):
        checkpoint = torch.load(save_name, map_location=device)
        vae_net.load_state_dict(checkpoint["net"])
        optimizer.load_state_dict(checkpoint["optimizer"])
        for g in optimizer.param_groups:
            g['lr'] = lr

max_epochs = 100
early_stop = EarlyStop(patience=10, save_name=save_name)
# Out:
# Model parameters have already been trained before. Retrain ? (y/n)

# %% [markdown]
# Training the network

# %%
plt.ion()
print("training on ", device)
for epoch in range(max_epochs):
    vae_net.train()
    train_loss, n, start = 0.0, 0, time.time()
    for X, y in tqdm.tqdm(train_iter, ncols=50):
        X = X.to(device)
        # only use the first dimension of y
        y = y[:, 0].to(device)
        X_hat, mean, logvar = vae_net(X, y)

        l = vae_net.loss(X, X_hat, mean, logvar).to(device)
        optimizer.zero_grad()
        l.backward()
        optimizer.step()

        train_loss += l.cpu().item()
        n += X.shape[0]

    train_loss /= n
    print('epoch %d, train loss %.4f , time %.1f sec'
          % (epoch, train_loss, time.time() - start))

    adjust_lr(optimizer)

    # ------------ plot the training result ------------
    check_number = 5
    if epoch % 10 == 0:
        for i in range(X.shape[0]):
            if y[i] == check_number:
                data = X[i, :, :].cpu().numpy()
                data1 = X_hat[i, :, :].detach().cpu().numpy()
                # plot the data with red line
                # add title
                plt.title("epoch " + str(epoch))
                plt.plot(data[0, :], "r")
                plt.plot(data1[0, :], "b")
                # plot legend
                plt.legend(["original", "reconstruction"])
                plt.show()

                plt.plot(data[1, :], "r")
                plt.plot(data1[1, :], "b")
                plt.legend(["original", "reconstruction"])
                plt.show()

    if (early_stop(train_loss, vae_net, optimizer)):
        break
# Out:
# training on  cuda
# 100%|██████████| 782/782 [00:02<00:00, 292.42it/s]
# epoch 0, train loss 0.0000 , time 2.7 sec
# 100%|██████████| 782/782 [00:02<00:00, 385.32it/s]
# epoch 1, train loss 0.0000 , time 2.0 sec
# 100%|██████████| 782/782 [00:02<00:00, 371.82it/s]
# epoch 2, train loss 0.0000 , time 2.1 sec
# 100%|██████████| 782/782 [00:02<00:00, 372.29it/s]
# epoch 3, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:01<00:00, 395.97it/s]
# epoch 4, train loss 0.0000 , time 2.0 sec
# 100%|██████████| 782/782 [00:02<00:00, 358.35it/s]
# epoch 5, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:01<00:00, 392.23it/s]
# epoch 6, train loss 0.0000 , time 2.0 sec
# 100%|██████████| 782/782 [00:02<00:00, 353.20it/s]
# epoch 7, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 355.30it/s]
# epoch 8, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 354.87it/s]
# epoch 9, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 355.13it/s]
# epoch 10, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 352.31it/s]
# epoch 11, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 370.57it/s]
# epoch 12, train loss 0.0000 , time 2.1 sec
# 100%|██████████| 782/782 [00:02<00:00, 356.58it/s]
# epoch 13, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 373.77it/s]
# epoch 14, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 2 out of 10
# 100%|██████████| 782/782 [00:01<00:00, 395.55it/s]
# epoch 15, train loss 0.0000 , time 2.0 sec
# 100%|██████████| 782/782 [00:02<00:00, 373.63it/s]
# epoch 16, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 353.83it/s]
# epoch 17, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 374.94it/s]
# epoch 18, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 353.43it/s]
# epoch 19, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 352.61it/s]
# epoch 20, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 350.25it/s]
# epoch 21, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 356.30it/s]
# epoch 22, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 353.47it/s]
# epoch 23, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 385.28it/s]
# epoch 24, train loss 0.0000 , time 2.0 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 380.05it/s]
# epoch 25, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 2 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 387.88it/s]
# epoch 26, train loss 0.0000 , time 2.0 sec
# 100%|██████████| 782/782 [00:02<00:00, 377.62it/s]
# epoch 27, train loss 0.0000 , time 2.1 sec
# 100%|██████████| 782/782 [00:02<00:00, 347.76it/s]
# epoch 28, train loss 0.0000 , time 2.3 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 355.45it/s]
# epoch 29, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 2 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 356.22it/s]
# epoch 30, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 3 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 356.49it/s]
# epoch 31, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 366.23it/s]
# epoch 32, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 371.18it/s]
# epoch 33, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 2 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 343.60it/s]
# epoch 34, train loss 0.0000 , time 2.3 sec
# EarlyStopping counter: 3 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 356.68it/s]
# epoch 35, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 4 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 353.91it/s]
# epoch 36, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 359.97it/s]
# epoch 37, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:01<00:00, 397.55it/s]
# epoch 38, train loss 0.0000 , time 2.0 sec
# 100%|██████████| 782/782 [00:02<00:00, 351.96it/s]
# epoch 39, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 356.33it/s]
# epoch 40, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 372.24it/s]
# epoch 41, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 390.84it/s]
# epoch 42, train loss 0.0000 , time 2.0 sec
# 100%|██████████| 782/782 [00:02<00:00, 378.69it/s]
# epoch 43, train loss 0.0000 , time 2.1 sec
# 100%|██████████| 782/782 [00:02<00:00, 382.00it/s]
# epoch 44, train loss 0.0000 , time 2.0 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 366.06it/s]
# epoch 45, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 2 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 375.76it/s]
# epoch 46, train loss 0.0000 , time 2.1 sec
# 100%|██████████| 782/782 [00:02<00:00, 382.13it/s]
# epoch 47, train loss 0.0000 , time 2.0 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 377.74it/s]
# epoch 48, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 2 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 364.25it/s]
# epoch 49, train loss 0.0000 , time 2.1 sec
# 100%|██████████| 782/782 [00:02<00:00, 339.44it/s]
# epoch 50, train loss 0.0000 , time 2.3 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 388.33it/s]
# epoch 51, train loss 0.0000 , time 2.0 sec
# EarlyStopping counter: 2 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 372.62it/s]
# epoch 52, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 3 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 375.31it/s]
# epoch 53, train loss 0.0000 , time 2.1 sec
# 100%|██████████| 782/782 [00:02<00:00, 359.93it/s]
# epoch 54, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 336.69it/s]
# epoch 55, train loss 0.0000 , time 2.3 sec
# 100%|██████████| 782/782 [00:02<00:00, 347.83it/s]
# epoch 56, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 383.89it/s]
# epoch 57, train loss 0.0000 , time 2.0 sec
# EarlyStopping counter: 2 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 388.59it/s]
# epoch 58, train loss 0.0000 , time 2.0 sec
# EarlyStopping counter: 3 out of 10
# 100%|██████████| 782/782 [00:01<00:00, 395.88it/s]
# epoch 59, train loss 0.0000 , time 2.0 sec
# EarlyStopping counter: 4 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 349.04it/s]
# epoch 60, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 5 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 350.41it/s]
# epoch 61, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 6 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 352.91it/s]
# epoch 62, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 7 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 351.36it/s]
# epoch 63, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 8 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 355.40it/s]
# epoch 64, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 9 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 345.51it/s]
# epoch 65, train loss 0.0000 , time 2.3 sec
# 100%|██████████| 782/782 [00:02<00:00, 381.11it/s]
# epoch 66, train loss 0.0000 , time 2.1 sec
# 100%|██████████| 782/782 [00:02<00:00, 360.28it/s]
# epoch 67, train loss 0.0000 , time 2.2 sec
# 100%|██████████| 782/782 [00:02<00:00, 379.90it/s]
# epoch 68, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 1 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 351.32it/s]
# epoch 69, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 2 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 357.57it/s]
# epoch 70, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 3 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 369.33it/s]
# epoch 71, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 4 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 361.03it/s]
# epoch 72, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 5 out of 10
# 100%|██████████| 782/782 [00:01<00:00, 395.94it/s]
# epoch 73, train loss 0.0000 , time 2.0 sec
# EarlyStopping counter: 6 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 375.53it/s]
# epoch 74, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 7 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 349.14it/s]
# epoch 75, train loss 0.0000 , time 2.2 sec
# EarlyStopping counter: 8 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 375.17it/s]
# epoch 76, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 9 out of 10
# 100%|██████████| 782/782 [00:02<00:00, 368.36it/s]
# epoch 77, train loss 0.0000 , time 2.1 sec
# EarlyStopping counter: 10 out of 10

# %% [markdown]
# Generate trajectory from the torque

# %%
vae_net.eval()
number = 3
for i in range(10):
    with torch.no_grad():
        torque = vae_net.generate(number)    
    # plot the generated force
    plt.plot(torque[:, 0, :].cpu().T, torque[:, 1, :].cpu().T)

# %% [markdown]
# denormalize the data

# %%
real_torque = train_dataset.denormalize_data(torque)
print(real_torque.shape)
plt.plot(real_torque[:, 0, :].cpu().T, real_torque[:, 1, :].cpu().T, "b", linewidth=5)
# Out:
# torch.Size([1, 2, 100])

# %% [markdown]
# Generate trajectory by DM system

# %%
ax = 25
bx = ax/4
dt = 0.01
x0 = np.array([0, 1]).T

dm = DM(ax=ax, bx=bx, ndof=2, dt=dt)

goal = np.array([0.2, 0]).T

# forward to get the trajectory
traj = dm(real_torque, goal=goal, x0=x0)
traj.shape
plt.plot(traj[:, 0, :].cpu().T, traj[:, 1, :].cpu().T, "b", linewidth=5)

# %%
y0 = np.array([[0, 1]])
print(y0.shape)
goal = np.array([[0.2, 0]])
# Out:
# (1, 2)

# %%
dmp_traj = vae_net.get_trajectory(real_torque, y0, goal)
plt.plot(dmp_traj[:, 0, :].T, dmp_traj[:, 1, :].T, "b")
